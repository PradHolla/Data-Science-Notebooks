# %%
import cv2
import os
import matplotlib.pyplot as plt

# %%
img_path = os.path.join('Data', '2.jpg')

# %%
img_path
# Out:
# 'Data\\2.jpg'

# %%
img = cv2.imread(img_path)

# %%
img.shape
# Out:
# (3452, 5472, 3)

# %%
plt.imshow(img)

# %%
recolor = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray)
plt.show()

# %%
cv2.imwrite('Data/gray.jpg', gray)
# Out:
# True
